# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-A01793650/blob/main/Modulo5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('assignment01 for GitJobish03 and edited in git, and 18')
# Out:
# assignment01 for GitJobish03 and edited in git, and 18

# %% [markdown]
# texto en cursiva## **Módulo 5**
#
# A01793650![IBM_Progress.PNG](data:image/png;base64,...)

# %%
import numpy as np

# %% [markdown]
# #*Quiz*
# What is the result of the following operation: np.array([1,-1])*np.array([1,1])?

# %%
np.array([1,-1])*np.array([1,1])
# Out:
# array([ 1, -1])

# %% [markdown]
# What is the result of the following operation: np.dot(np.array([1,-1]),np.array([1,1]))?

# %%
np.dot(np.array([1,-1]),np.array([1,1]))
# Out:
# 0
